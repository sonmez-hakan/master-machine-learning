# %% [markdown]
# ## Transaction Veri Setinin Analizinin Yapılması

# %%
import time
import json
import itertools
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

pd.set_option("display.precision", 2)
frac = 0.00002

# %% [markdown]
# Veri satırı her bir satırda JSON türünde verilerden oluştuğu için (dosyanın kendisi geçerli bir json değildir) dosyadaki veri seti satır satır okunup bir araya getirilmiştir. Ayırca boş string ifadeleri NaN ile değiştirilmiştir.

# %%
directory = r'/content/drive/MyDrive/Colab Notebooks/Project/Datasets/transactions.txt'


with open(directory) as txt_file:
    lines = txt_file.readlines()

dataset = []
for line in lines:
    dataset.append(json.loads(line))

dataset = pd.DataFrame(dataset)
dataset = dataset.replace(r'', np.NaN)

# %% [markdown]
# ## Özniteliklerin incelenmesi

# %%
dataset.columns
# Out:
# Index(['accountNumber', 'customerId', 'creditLimit', 'availableMoney',
#        'transactionDateTime', 'transactionAmount', 'merchantName',
#        'acqCountry', 'merchantCountryCode', 'posEntryMode', 'posConditionCode',
#        'merchantCategoryCode', 'currentExpDate', 'accountOpenDate',
#        'dateOfLastAddressChange', 'cardCVV', 'enteredCVV', 'cardLast4Digits',
#        'transactionType', 'echoBuffer', 'currentBalance', 'merchantCity',
#        'merchantState', 'merchantZip', 'cardPresent', 'posOnPremises',
#        'recurringAuthInd', 'expirationDateKeyInMatch', 'isFraud'],
#       dtype='object')

# %%
print("Satır Sayısı: {}".format(dataset.shape[0]))
print("Öznitelik Syısı: {}".format(dataset.shape[1]))
print("Fraud İşlem Sayısı: {}".format(dataset[dataset['isFraud'] == 1].shape[0]))
# Out:
# Satır Sayısı: 786363
# Öznitelik Syısı: 29
# Fraud İşlem Sayısı: 12417

# %%
dataset.sample(frac=frac)
# Out:
#        accountNumber customerId  creditLimit  availableMoney  \
# 150256     204494014  204494014       2500.0          317.18
# 101189     249676988  249676988       7500.0         1544.96
# 165991     667520057  667520057       5000.0         4863.19
# 332717     748304722  748304722      15000.0         6682.60
# 272148     380680241  380680241       5000.0         2560.19
# 155503     360252317  360252317       2500.0          204.44
# 628706     982489153  982489153      20000.0         4794.81
# 596698     977774995  977774995       2500.0          826.52
# 310142     441663479  441663479       1000.0          478.59
# 66997      839626053  839626053        500.0          361.16
# 248737     380680241  380680241       5000.0         3926.62
# 542873     553545372  553545372       1000.0         1000.00
# 277162     927230788  927230788       5000.0         2073.54
# 28680      718949146  718949146      20000.0        18455.40
# 327539     767620004  767620004      15000.0         5920.93
# 744483     924070882  924070882       2500.0          634.13
#
#         transactionDateTime  transactionAmount                   merchantName  \
# 150256  2016-06-10T22:17:08              13.22                   discount.com
# 101189  2016-10-23T18:05:24              26.50            Rodeway Inn #268900
# 165991  2016-03-16T07:13:51              88.34                       ebay.com
# 332717  2016-06-10T16:06:54             296.53                     target.com
# 272148  2016-12-21T01:27:15              25.59  Blue Mountain Online Services
# 155503  2016-05-10T12:45:14               0.00            Shake Shack #124891
# 628706  2016-11-29T03:51:31              30.38                 Subway #821396
# 596698  2016-08-18T04:30:33             149.03                      apple.com
# 310142  2016-09-11T04:09:14              47.07                        gap.com
# 66997   2016-09-24T09:19:31             245.45               Quizno's #756653
# 248737  2016-04-03T23:19:38             119.35           Blue Mountain eCards
# 542873  2016-03-29T11:54:07             324.77          Fresh Online Services
# 277162  2016-10-28T12:12:41              53.76                       West Elm
# 28680   2016-04-28T12:55:26             143.03                Next Day eCards
# 327539  2016-06-30T08:11:06             467.36       Universe Massage #350895
# 744483  2016-07-03T14:46:29              23.13             San Francisco Post
#
#        acqCountry merchantCountryCode posEntryMode  ... echoBuffer  \
# 150256         US                  US           09  ...        NaN
# 101189         US                  US           05  ...        NaN
# 165991         US                  US           09  ...        NaN
# 332717         US                  US           05  ...        NaN
# 272148        NaN                 NaN           09  ...        NaN
# 155503         US                  US           05  ...        NaN
# 628706         US                  US           05  ...        NaN
# 596698         US                  US           09  ...        NaN
# 310142         PR                  PR           09  ...        NaN
# 66997          US                  US           02  ...        NaN
# 248737         US                  US           09  ...        NaN
# 542873         US                  US           05  ...        NaN
# 277162         US                  US           02  ...        NaN
# 28680          US                  US           90  ...        NaN
# 327539         US                  US           05  ...        NaN
# 744483         US                  US           05  ...        NaN
#
#        currentBalance merchantCity merchantState merchantZip cardPresent  \
# 150256        2182.82          NaN           NaN         NaN       False
# 101189        5955.04          NaN           NaN         NaN       False
# 165991         136.81          NaN           NaN         NaN       False
# 332717        8317.40          NaN           NaN         NaN       False
# 272148        2439.81          NaN           NaN         NaN       False
# 155503        2295.56          NaN           NaN         NaN       False
# 628706       15205.19          NaN           NaN         NaN        True
# 596698        1673.48          NaN           NaN         NaN       False
# 310142         521.41          NaN           NaN         NaN       False
# 66997          138.84          NaN           NaN         NaN        True
# 248737        1073.38          NaN           NaN         NaN       False
# 542873           0.00          NaN           NaN         NaN       False
# 277162        2926.46          NaN           NaN         NaN        True
# 28680         1544.60          NaN           NaN         NaN       False
# 327539        9079.07          NaN           NaN         NaN        True
# 744483        1865.87          NaN           NaN         NaN       False
#
#        posOnPremises recurringAuthInd expirationDateKeyInMatch  isFraud
# 150256           NaN              NaN                    False    False
# 101189           NaN              NaN                    False    False
# 165991           NaN              NaN                    False    False
# 332717           NaN              NaN                    False    False
# 272148           NaN              NaN                    False    False
# 155503           NaN              NaN                    False    False
# 628706           NaN              NaN                    False    False
# 596698           NaN              NaN                    False    False
# 310142           NaN              NaN                    False    False
# 66997            NaN              NaN                    False    False
# 248737           NaN              NaN                    False    False
# 542873           NaN              NaN                    False    False
# 277162           NaN              NaN                    False    False
# 28680            NaN              NaN                    False    False
# 327539           NaN              NaN                    False    False
# 744483           NaN              NaN                    False    False
#
# [16 rows x 29 columns]

# %% [markdown]
# Verilerin sütunlara göre kaç adet non-null veri içerdiği ve veri tipinin gösterimi yapılmıştır.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786363 entries, 0 to 786362
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             786363 non-null  object
#  1   customerId                786363 non-null  object
#  2   creditLimit               786363 non-null  float64
#  3   availableMoney            786363 non-null  float64
#  4   transactionDateTime       786363 non-null  object
#  5   transactionAmount         786363 non-null  float64
#  6   merchantName              786363 non-null  object
#  7   acqCountry                781801 non-null  object
#  8   merchantCountryCode       785639 non-null  object
#  9   posEntryMode              782309 non-null  object
#  10  posConditionCode          785954 non-null  object
#  11  merchantCategoryCode      786363 non-null  object
#  12  currentExpDate            786363 non-null  object
#  13  accountOpenDate           786363 non-null  object
#  14  dateOfLastAddressChange   786363 non-null  object
#  15  cardCVV                   786363 non-null  object
#  16  enteredCVV                786363 non-null  object
#  17  cardLast4Digits           786363 non-null  object
#  18  transactionType           785665 non-null  object
#  19  echoBuffer                0 non-null       float64
#  20  currentBalance            786363 non-null  float64
#  21  merchantCity              0 non-null       float64
#  22  merchantState             0 non-null       float64
#  23  merchantZip               0 non-null       float64
#  24  cardPresent               786363 non-null  bool
#  25  posOnPremises             0 non-null       float64
#  26  recurringAuthInd          0 non-null       float64
#  27  expirationDateKeyInMatch  786363 non-null  bool
#  28  isFraud                   786363 non-null  bool
# dtypes: bool(3), float64(10), object(16)
# memory usage: 158.2+ MB

# %%
dataset.isnull().sum()
# Out:
# accountNumber                    0
# customerId                       0
# creditLimit                      0
# availableMoney                   0
# transactionDateTime              0
# transactionAmount                0
# merchantName                     0
# acqCountry                    4562
# merchantCountryCode            724
# posEntryMode                  4054
# posConditionCode               409
# merchantCategoryCode             0
# currentExpDate                   0
# accountOpenDate                  0
# dateOfLastAddressChange          0
# cardCVV                          0
# enteredCVV                       0
# cardLast4Digits                  0
# transactionType                698
# echoBuffer                  786363
# currentBalance                   0
# merchantCity                786363
# merchantState               786363
# merchantZip                 786363
# cardPresent                      0
# posOnPremises               786363
# recurringAuthInd            786363
# expirationDateKeyInMatch         0
# isFraud                          0
# dtype: int64

# %%
dataset.drop(['echoBuffer', 'merchantCity', 'merchantState', 'merchantZip', 'posOnPremises', 'recurringAuthInd'], axis=1, inplace=True)

# %% [markdown]
# Null dolu olan öznitelikelr düşürüldükten sonra tekrardan veri setinin bilgileri gösterilmiştir.

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786363 entries, 0 to 786362
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   accountNumber             786363 non-null  object
#  1   customerId                786363 non-null  object
#  2   creditLimit               786363 non-null  float64
#  3   availableMoney            786363 non-null  float64
#  4   transactionDateTime       786363 non-null  object
#  5   transactionAmount         786363 non-null  float64
#  6   merchantName              786363 non-null  object
#  7   acqCountry                781801 non-null  object
#  8   merchantCountryCode       785639 non-null  object
#  9   posEntryMode              782309 non-null  object
#  10  posConditionCode          785954 non-null  object
#  11  merchantCategoryCode      786363 non-null  object
#  12  currentExpDate            786363 non-null  object
#  13  accountOpenDate           786363 non-null  object
#  14  dateOfLastAddressChange   786363 non-null  object
#  15  cardCVV                   786363 non-null  object
#  16  enteredCVV                786363 non-null  object
#  17  cardLast4Digits           786363 non-null  object
#  18  transactionType           785665 non-null  object
#  19  currentBalance            786363 non-null  float64
#  20  cardPresent               786363 non-null  bool
#  21  expirationDateKeyInMatch  786363 non-null  bool
#  22  isFraud                   786363 non-null  bool
# dtypes: bool(3), float64(4), object(16)
# memory usage: 122.2+ MB

# %%
dataset.isnull().sum()
# Out:
# accountNumber                  0
# customerId                     0
# creditLimit                    0
# availableMoney                 0
# transactionDateTime            0
# transactionAmount              0
# merchantName                   0
# acqCountry                  4562
# merchantCountryCode          724
# posEntryMode                4054
# posConditionCode             409
# merchantCategoryCode           0
# currentExpDate                 0
# accountOpenDate                0
# dateOfLastAddressChange        0
# cardCVV                        0
# enteredCVV                     0
# cardLast4Digits                0
# transactionType              698
# currentBalance                 0
# cardPresent                    0
# expirationDateKeyInMatch       0
# isFraud                        0
# dtype: int64

# %% [markdown]
# Eksik Değerlerin Görselleştirilmesi

# %%
plt.figure(figsize=(15,6))
dataset.isnull().sum().plot(kind = 'barh', color='black')
plt.xlabel('Eksik Değer Sayıları', fontsize=14)
plt.ylabel('Öznitelikler', fontsize=14)
plt.title('Eksik Değer Sayıları ve Öznitelikler', fontsize=18)
plt.show();

# %%
dataset.describe().T
# Out:
#                       count      mean       std      min      25%      50%  \
# creditLimit        786363.0  10759.46  11636.17   250.00  5000.00  7500.00
# availableMoney     786363.0   6250.73   8880.78 -1005.63  1077.42  3184.86
# transactionAmount  786363.0    136.99    147.73     0.00    33.65    87.90
# currentBalance     786363.0   4508.74   6457.44     0.00   689.91  2451.76
#
#                         75%       max
# creditLimit        15000.00  50000.00
# availableMoney      7500.00  50000.00
# transactionAmount    191.48   2011.54
# currentBalance      5291.10  47498.81

# %% [markdown]
# Kategorik Değişkenlerin de incelenmesi görülmüştür.

# %%
dataset.describe(include = "all").T
# Out:
#                              count  unique                  top    freq  \
# accountNumber               786363    5000            380680241   32850
# customerId                  786363    5000            380680241   32850
# creditLimit               786363.0     NaN                  NaN     NaN
# availableMoney            786363.0     NaN                  NaN     NaN
# transactionDateTime         786363  776637  2016-12-25T14:04:15       4
# transactionAmount         786363.0     NaN                  NaN     NaN
# merchantName                786363    2490                 Uber   25613
# acqCountry                  781801       4                   US  774709
# merchantCountryCode         785639       4                   US  778511
# posEntryMode                782309       5                   05  315035
# posConditionCode            785954       3                   01  628787
# merchantCategoryCode        786363      19        online_retail  202156
# currentExpDate              786363     165              03/2029    5103
# accountOpenDate             786363    1820           2014-06-21   33623
# dateOfLastAddressChange     786363    2184           2016-03-15    3819
# cardCVV                     786363     899                  869   33749
# enteredCVV                  786363     976                  869   33424
# cardLast4Digits             786363    5246                  593   32946
# transactionType             785665       3             PURCHASE  745193
# currentBalance            786363.0     NaN                  NaN     NaN
# cardPresent                 786363       2                False  433495
# expirationDateKeyInMatch    786363       2                False  785320
# isFraud                     786363       2                False  773946
#
#                               mean       std      min      25%      50%  \
# accountNumber                  NaN       NaN      NaN      NaN      NaN
# customerId                     NaN       NaN      NaN      NaN      NaN
# creditLimit               10759.46  11636.17    250.0   5000.0   7500.0
# availableMoney             6250.73   8880.78 -1005.63  1077.42  3184.86
# transactionDateTime            NaN       NaN      NaN      NaN      NaN
# transactionAmount           136.99    147.73      0.0    33.65     87.9
# merchantName                   NaN       NaN      NaN      NaN      NaN
# acqCountry                     NaN       NaN      NaN      NaN      NaN
# merchantCountryCode            NaN       NaN      NaN      NaN      NaN
# posEntryMode                   NaN       NaN      NaN      NaN      NaN
# posConditionCode               NaN       NaN      NaN      NaN      NaN
# merchantCategoryCode           NaN       NaN      NaN      NaN      NaN
# currentExpDate                 NaN       NaN      NaN      NaN      NaN
# accountOpenDate                NaN       NaN      NaN      NaN      NaN
# dateOfLastAddressChange        NaN       NaN      NaN      NaN      NaN
# cardCVV                        NaN       NaN      NaN      NaN      NaN
# enteredCVV                     NaN       NaN      NaN      NaN      NaN
# cardLast4Digits                NaN       NaN      NaN      NaN      NaN
# transactionType                NaN       NaN      NaN      NaN      NaN
# currentBalance             4508.74   6457.44      0.0   689.91  2451.76
# cardPresent                    NaN       NaN      NaN      NaN      NaN
# expirationDateKeyInMatch       NaN       NaN      NaN      NaN      NaN
# isFraud                        NaN       NaN      NaN      NaN      NaN
#
#                               75%       max
# accountNumber                 NaN       NaN
# customerId                    NaN       NaN
# creditLimit               15000.0   50000.0
# availableMoney             7500.0   50000.0
# transactionDateTime           NaN       NaN
# transactionAmount          191.48   2011.54
# merchantName                  NaN       NaN
# acqCountry                    NaN       NaN
# merchantCountryCode           NaN       NaN
# posEntryMode                  NaN       NaN
# posConditionCode              NaN       NaN
# merchantCategoryCode          NaN       NaN
# currentExpDate                NaN       NaN
# accountOpenDate               NaN       NaN
# dateOfLastAddressChange       NaN       NaN
# cardCVV                       NaN       NaN
# enteredCVV                    NaN       NaN
# cardLast4Digits               NaN       NaN
# transactionType               NaN       NaN
# currentBalance             5291.1  47498.81
# cardPresent                   NaN       NaN
# expirationDateKeyInMatch      NaN       NaN
# isFraud                       NaN       NaN

# %% [markdown]
# ## Kategorik Özniteliklerin incelenmesi

# %%
categoricalColumns = dataset.select_dtypes(include = ["object"])

# %%
categoricalColumns.sample(frac=frac)
# Out:
#        accountNumber customerId  transactionDateTime  \
# 119975     338573453  338573453  2016-04-18T06:30:16
# 605157     411498935  411498935  2016-11-25T02:10:21
# 777703     198092241  198092241  2016-10-18T22:46:33
# 547135     307632490  307632490  2016-03-08T00:04:32
# 621457     456184078  456184078  2016-07-10T11:17:26
# 2428       130517112  130517112  2016-06-16T06:29:19
# 643679     230752735  230752735  2016-01-06T16:34:22
# 684500     708011039  708011039  2016-12-07T08:44:56
# 37577      442799740  442799740  2016-01-24T23:46:23
# 348538     376046958  376046958  2016-06-06T21:55:20
# 715974     133105237  133105237  2016-06-17T15:58:15
# 595727     131781378  131781378  2016-02-21T01:38:47
# 678199     380083836  380083836  2016-01-13T20:45:04
# 16852      863456981  863456981  2016-03-26T19:57:48
# 311947     326866174  326866174  2016-10-11T20:37:15
# 359211     382967566  382967566  2016-04-22T13:42:46
#
#                     merchantName acqCountry merchantCountryCode posEntryMode  \
# 119975      EZ Putt Putt #755869         US                  US           02
# 605157               AMC #552863         US                  US           02
# 777703            Bobs Furniture         US                  US           05
# 547135         Convenient Repair         US                  US           02
# 621457  Universe Massage #418883         US                  US           05
# 2428              Subway #185290         US                  US           09
# 643679             cheapfast.com         US                  US           05
# 684500                  ebay.com         US                  US           05
# 37577                AMC #606218         US                  US           05
# 348538  Next Day Online Services         US                  US           05
# 715974               AMC #706324         US                  US           90
# 595727             Boston Bistro         US                  US           09
# 678199      Krispy Kreme #827835         US                  US           05
# 16852                       Lyft         US                  US           09
# 311947        Sunoco Gas #871034         US                  US           09
# 359211                      Uber         US                  US           09
#
#        posConditionCode merchantCategoryCode currentExpDate accountOpenDate  \
# 119975               08        entertainment        09/2029      2008-12-20
# 605157               08        entertainment        10/2026      2015-03-19
# 777703               01            furniture        09/2022      2014-12-14
# 547135               08                 auto        03/2021      2015-08-14
# 621457               01        personal care        08/2030      2015-06-06
# 2428                 01             fastfood        12/2028      2013-06-16
# 643679               01        online_retail        07/2029      2014-12-06
# 684500               01        online_retail        03/2025      2014-05-23
# 37577                01        entertainment        11/2024      2015-10-28
# 348538               01         online_gifts        06/2033      2014-01-28
# 715974               01        entertainment        07/2030      2015-12-23
# 595727               01                 food        12/2029      2012-08-22
# 678199               01             fastfood        04/2033      2015-12-23
# 16852                01            rideshare        11/2028      2014-07-23
# 311947               01                 fuel        10/2032      2013-08-11
# 359211               01            rideshare        03/2023      2015-01-27
#
#        dateOfLastAddressChange cardCVV enteredCVV cardLast4Digits  \
# 119975              2008-12-20     222        222            9417
# 605157              2015-03-19     322        322            1392
# 777703              2016-09-06     296        296            3156
# 547135              2016-01-03     400        400            4434
# 621457              2015-06-06     690        690            3013
# 2428                2013-06-16     205        205            1317
# 643679              2014-12-06     372        372            2053
# 684500              2014-05-23     331        331            6524
# 37577               2015-10-28     494        494            3018
# 348538              2016-01-19     812        812            2153
# 715974              2016-06-09     706        706            6220
# 595727              2012-08-22     475        475            5635
# 678199              2015-12-23     738        738            7185
# 16852               2014-07-23     652        652            6236
# 311947              2013-08-11     455        455            5609
# 359211              2016-01-17     866        866            1309
#
#              transactionType
# 119975              PURCHASE
# 605157              REVERSAL
# 777703              PURCHASE
# 547135              PURCHASE
# 621457              PURCHASE
# 2428                PURCHASE
# 643679              PURCHASE
# 684500              PURCHASE
# 37577               PURCHASE
# 348538              PURCHASE
# 715974              PURCHASE
# 595727              PURCHASE
# 678199  ADDRESS_VERIFICATION
# 16852               PURCHASE
# 311947              PURCHASE
# 359211              PURCHASE

# %%
categoricalColumns["merchantCategoryCode"].unique()
# Out:
# array(['rideshare', 'entertainment', 'mobileapps', 'fastfood',
#        'food_delivery', 'auto', 'online_retail', 'gym', 'health',
#        'personal care', 'food', 'fuel', 'online_subscriptions',
#        'online_gifts', 'hotels', 'airline', 'furniture', 'subscriptions',
#        'cable/phone'], dtype=object)

# %%
categoricalColumns["merchantCategoryCode"].value_counts()
# Out:
# online_retail           202156
# fastfood                112138
# entertainment            80098
# food                     75490
# online_gifts             66238
# rideshare                51136
# hotels                   34097
# fuel                     23910
# subscriptions            22901
# auto                     21651
# health                   19092
# personal care            18964
# airline                  15412
# mobileapps               14990
# online_subscriptions     11067
# furniture                 7432
# food_delivery             6000
# gym                       2209
# cable/phone               1382
# Name: merchantCategoryCode, dtype: int64

# %%
categoricalColumns["merchantCategoryCode"].value_counts().plot.barh();

# %%
merchantCategoryCode = dataset["merchantCategoryCode"].value_counts()
transactions = merchantCategoryCode.index
quantity = merchantCategoryCode.values
figure = px.pie(dataset, values=quantity, names=transactions, hole = 0.5, title="Satıcıların Kategorilerine Göre işlemlerin Dağılımı")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="186e408b-6bdc-4ee2-94aa-1463429f98ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("186e408b-6bdc-4ee2-94aa-1463429f98ea")) {                    Plotly.newPlot(                        "186e408b-6bdc-4ee2-94aa-1463429f98ea",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["online_retail","fastfood","entertainment","food","online_gifts","rideshare","hotels","fuel","subscriptions","auto","health","personal care","airline","mobileapps","online_subscriptions","furniture","food_delivery","gym","cable/phone"],"legendgroup":"","name":"","showlegend":true,"values":[202156,112138,80098,75490,66238,51136,34097,23910,22901,21651,19092,18964,15412,14990,11067,7432,6000,2209,1382],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outline ...

# %% [markdown]
# Kategorik Değikenlerin gruplara göre sayıları gösterilmiştir.

# %%
selectedColumns = ['transactionType', 'acqCountry', 'posEntryMode', 'posConditionCode', 'merchantCategoryCode']
(pd.DataFrame(
    dataset[selectedColumns]
    .melt(var_name='column', value_name='value')
    .value_counts())
.rename(columns={0: 'counts'})
.sort_values(by=['column', 'counts']))
# Out:
#                                            counts
# column               value
# acqCountry           PR                      1538
#                      CAN                     2424
#                      MEX                     3130
#                      US                    774709
# merchantCategoryCode cable/phone             1382
#                      gym                     2209
#                      food_delivery           6000
#                      furniture               7432
#                      online_subscriptions   11067
#                      mobileapps             14990
#                      airline                15412
#                      personal care          18964
#                      health                 19092
#                      auto                   21651
#                      subscriptions          22901
#                      fuel                   23910
#                      hotels                 34097
#                      rideshare              51136
#                      online_gifts           66238
#                      food                   75490
#                      entertainment          80098
#                      fastfood              112138
#                      online_retail         202156
# posConditionCode     99                      7533
#                      08                    149634
#                      01                    628787
# posEntryMode         80                     15283
#                      90                     19576
#                      02                    195934
#                      09                    236481
#                      05                    315035
# transactionType      ADDRESS_VERIFICATION   20169
#                      REVERSAL               20303
#                      PURCHASE              745193

# %% [markdown]
# ## Veri setinin özniteliklerinin arasındaki ilişkinin incelenmesi

# %%
dataset.corr()
# Out:
#                           creditLimit  availableMoney  transactionAmount  \
# creditLimit                  1.00e+00        8.35e-01           5.58e-03
# availableMoney               8.35e-01        1.00e+00          -1.01e-02
# transactionAmount            5.58e-03       -1.01e-02           1.00e+00
# currentBalance               6.54e-01        1.29e-01           2.39e-02
# cardPresent                 -3.93e-03        2.51e-03           3.74e-02
# expirationDateKeyInMatch     2.39e-03        4.07e-03           1.75e-03
# isFraud                      3.11e-03       -1.54e-03           7.57e-02
#
#                           currentBalance  cardPresent  \
# creditLimit                     6.54e-01    -3.93e-03
# availableMoney                  1.29e-01     2.51e-03
# transactionAmount               2.39e-02     3.74e-02
# currentBalance                  1.00e+00    -1.05e-02
# cardPresent                    -1.05e-02     1.00e+00
# expirationDateKeyInMatch       -1.28e-03     4.04e-02
# isFraud                         7.72e-03    -4.34e-02
#
#                           expirationDateKeyInMatch   isFraud
# creditLimit                               2.39e-03  3.11e-03
# availableMoney                            4.07e-03 -1.54e-03
# transactionAmount                         1.75e-03  7.57e-02
# currentBalance                           -1.28e-03  7.72e-03
# cardPresent                               4.04e-02 -4.34e-02
# expirationDateKeyInMatch                  1.00e+00 -9.72e-04
# isFraud                                  -9.72e-04  1.00e+00

# %%
sns.heatmap(dataset.corr(), annot=True, cmap="Blues");

# %%
plt.figure(figsize=(20,3))
plt.scatter(dataset['availableMoney'], dataset['creditLimit'], c='blue');

# %%
sns.scatterplot(x="availableMoney", y="creditLimit", hue="transactionAmount", data=dataset.sample(frac=0.001));

# %% [markdown]
# Sayısal Değişkenlerin Dağılımı gösterilmiştir.

# %%
columns=['creditLimit','availableMoney','transactionAmount','currentBalance']

for column in columns:
    plt.xlabel(column)
    dataset[column].plot(kind='hist', bins=10, figsize=(12,6), facecolor='blue',edgecolor='black')
    plt.title(f"{column} Dağılımı")
    plt.show();
# Out:
# Text(0.5, 0, 'creditLimit')
# <AxesSubplot:xlabel='creditLimit', ylabel='Frequency'>
# Text(0.5, 1.0, 'creditLimit Dağılımı')
# Text(0.5, 0, 'availableMoney')
# <AxesSubplot:xlabel='availableMoney', ylabel='Frequency'>
# Text(0.5, 1.0, 'availableMoney Dağılımı')
# Text(0.5, 0, 'transactionAmount')
# <AxesSubplot:xlabel='transactionAmount', ylabel='Frequency'>
# Text(0.5, 1.0, 'transactionAmount Dağılımı')
# Text(0.5, 0, 'currentBalance')
# <AxesSubplot:xlabel='currentBalance', ylabel='Frequency'>
# Text(0.5, 1.0, 'currentBalance Dağılımı')

# %% [markdown]
# # **Özellik Ölçekleme**
#
# Aralarında değer farkı çok yüksek olan özellikleri ölçekleyerek, aralarındaki sayısal farkı azaltmış olduk.

# %%
from sklearn import preprocessing

# %%
numericColumns = dataset.loc[:, ['creditLimit','availableMoney','transactionAmount','currentBalance']]
norm = preprocessing.MinMaxScaler().fit(numericColumns)
datasetNorm = norm.transform(numericColumns)
datasetNorm
# Out:
# array([[0.09547739, 0.11774445, 0.04899231, 0.        ],
#        [0.09547739, 0.11774445, 0.03704127, 0.        ],
#        [0.09547739, 0.11774445, 0.00371357, 0.        ],
#        ...,
#        [1.        , 0.97580953, 0.02457321, 0.02597644],
#        [1.        , 0.97484042, 0.02480189, 0.0270171 ],
#        [1.        , 0.9738623 , 0.03588296, 0.02806744]])

# %%
pd.DataFrame(datasetNorm, columns=numericColumns.columns).plot.box(figsize=(20,5), rot=90);

# %%
numericColumns = dataset.loc[:, ['creditLimit','availableMoney','transactionAmount','currentBalance']]
norm = preprocessing.StandardScaler().fit(numericColumns)
datasetStd = norm.transform(numericColumns)
datasetStd
# Out:
# array([[-0.49496232, -0.14083511, -0.2601839 , -0.69822414],
#        [-0.49496232, -0.14083511, -0.42291819, -0.69822414],
#        [-0.49496232, -0.14083511, -0.87673295, -0.69822414],
#        ...,
#        [ 3.37229037,  4.78735343, -0.59269257, -0.50714991],
#        [ 3.37229037,  4.78178747, -0.58957868, -0.49949517],
#        [ 3.37229037,  4.77616972, -0.43869069, -0.4917692 ]])

# %%
pd.DataFrame(datasetStd, columns=numericColumns.columns).plot.box(figsize=(20,5), rot=90);
